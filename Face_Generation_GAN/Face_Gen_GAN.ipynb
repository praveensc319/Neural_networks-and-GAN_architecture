# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_07_2_Keras_gan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Nicely formatted time string
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60
    return "{}:{:>02}:{:>05.2f}".format(h, m, s)

# %%
try:
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)
    COLAB = True
    print("Note: using Google CoLab")
    # %tensorflow_version 2.x
except:
    print("Note: not using Google CoLab")
    COLAB = False
# Out:
# Mounted at /content/drive
# Note: using Google CoLab

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Reshape, Dropout, Dense 
from tensorflow.keras.layers import Flatten, BatchNormalization
from tensorflow.keras.layers import Activation, ZeroPadding2D
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.optimizers import Adam
import numpy as np
from PIL import Image
from tqdm import tqdm
import os 
import time
import matplotlib.pyplot as plt

# %%
# Generation resolution - Must be square 
# Training data is also scaled to this.
# Note GENERATE_RES 4 or higher  
# will blow Google CoLab's memory and have not
# been tested extensivly.
GENERATE_RES = 3 # Generation resolution factor 
# (1=32, 2=64, 3=96, 4=128, etc.)
GENERATE_SQUARE = 32 * GENERATE_RES # rows/cols (should be square)
IMAGE_CHANNELS = 3

# Preview image 
PREVIEW_ROWS = 4
PREVIEW_COLS = 7
PREVIEW_MARGIN = 16

# Size vector to generate images from
SEED_SIZE = 100

# Configuration
DATA_PATH = '/content/drive/My Drive/projects/faces'
EPOCHS = 400
BATCH_SIZE = 32
BUFFER_SIZE = 60000

print(f"Will generate {GENERATE_SQUARE}px square images.")
# Out:
# Will generate 96px square images.

# %%
# Image set has 11,682 images.  Can take over an hour 
# for initial preprocessing.
# Because of this time needed, save a Numpy preprocessed file.
# Note, that file is large enough to cause problems for 
# sume verisons of Pickle,
# so Numpy binary files are used.
training_binary_path = os.path.join(DATA_PATH,
        f'training_data_{GENERATE_SQUARE}_{GENERATE_SQUARE}.npy')

print(f"Looking for file: {training_binary_path}")

if not os.path.isfile(training_binary_path):
  start = time.time()
  print("Loading training images...")

  training_data = []
  faces_path = os.path.join(DATA_PATH,'face_images')
  for filename in tqdm(os.listdir(faces_path)):
      path = os.path.join(faces_path,filename)
      image = Image.open(path).resize((GENERATE_SQUARE,
            GENERATE_SQUARE),Image.ANTIALIAS)
      training_data.append(np.asarray(image))
  training_data = np.reshape(training_data,(-1,GENERATE_SQUARE,
            GENERATE_SQUARE,IMAGE_CHANNELS))
  training_data = training_data.astype(np.float32)
  training_data = training_data / 127.5 - 1.


  print("Saving training image binary...")
  np.save(training_binary_path,training_data)
  elapsed = time.time()-start
  print (f'Image preprocess time: {hms_string(elapsed)}')
else:
  print("Loading previous training pickle...")
  training_data = np.load(training_binary_path)
# Out:
# Looking for file: /content/drive/My Drive/projects/faces/training_data_96_96.npy
# Loading training images...
# 100%|██████████| 7864/7864 [31:10<00:00,  4.20it/s]
# Saving training image binary...
# Image preprocess time: 0:31:49.09

# %%
# Batch and shuffle the data
train_dataset = tf.data.Dataset.from_tensor_slices(training_data) \
    .shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %%
def build_generator(seed_size, channels):
    model = Sequential()

    model.add(Dense(4*4*256,activation="relu",input_dim=seed_size))
    model.add(Reshape((4,4,256)))

    model.add(UpSampling2D())
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))

    model.add(UpSampling2D())
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))
   
    # Output resolution, additional upsampling
    model.add(UpSampling2D())
    model.add(Conv2D(128,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))

    if GENERATE_RES>1:
      model.add(UpSampling2D(size=(GENERATE_RES,GENERATE_RES)))
      model.add(Conv2D(128,kernel_size=3,padding="same"))
      model.add(BatchNormalization(momentum=0.8))
      model.add(Activation("relu"))

    # Final CNN layer
    model.add(Conv2D(channels,kernel_size=3,padding="same"))
    model.add(Activation("tanh"))

    return model


def build_discriminator(image_shape):
    model = Sequential()

    model.add(Conv2D(32, kernel_size=3, strides=2, input_shape=image_shape, 
                     padding="same"))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(64, kernel_size=3, strides=2, padding="same"))
    model.add(ZeroPadding2D(padding=((0,1),(0,1))))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(128, kernel_size=3, strides=2, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(256, kernel_size=3, strides=1, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(512, kernel_size=3, strides=1, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1, activation='sigmoid'))

    return model

# %%
def save_images(cnt,noise):
  image_array = np.full(( 
      PREVIEW_MARGIN + (PREVIEW_ROWS * (GENERATE_SQUARE+PREVIEW_MARGIN)), 
      PREVIEW_MARGIN + (PREVIEW_COLS * (GENERATE_SQUARE+PREVIEW_MARGIN)), 3), 
      255, dtype=np.uint8)
  
  generated_images = generator.predict(noise)

  generated_images = 0.5 * generated_images + 0.5

  image_count = 0
  for row in range(PREVIEW_ROWS):
      for col in range(PREVIEW_COLS):
        r = row * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        c = col * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        image_array[r:r+GENERATE_SQUARE,c:c+GENERATE_SQUARE] \
            = generated_images[image_count] * 255
        image_count += 1

          
  output_path = os.path.join(DATA_PATH,'output')
  if not os.path.exists(output_path):
    os.makedirs(output_path)
  
  filename = os.path.join(output_path,f"train_3__-{cnt}.png")
  im = Image.fromarray(image_array)
  im.save(filename)

# %%
generator = build_generator(SEED_SIZE, IMAGE_CHANNELS)

noise = tf.random.normal([1, SEED_SIZE])
generated_image = generator(noise, training=False)

plt.imshow(generated_image[0, :, :, 0])

# %%
image_shape = (GENERATE_SQUARE,GENERATE_SQUARE,IMAGE_CHANNELS)

discriminator = build_discriminator(image_shape)
decision = discriminator(generated_image)
print (decision)
# Out:
# tf.Tensor([[0.49991313]], shape=(1, 1), dtype=float32)

# %%
# This method returns a helper function to compute cross entropy loss
cross_entropy = tf.keras.losses.BinaryCrossentropy()

def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# %%
generator_optimizer = tf.keras.optimizers.Adam(1.5e-4,0.5)
discriminator_optimizer = tf.keras.optimizers.Adam(1.5e-4,0.5)

# %%
# Notice the use of `tf.function`
# This annotation causes the function to be "compiled".
@tf.function
def train_step(images):
  seed = tf.random.normal([BATCH_SIZE, SEED_SIZE])

  with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
    generated_images = generator(seed, training=True)

    real_output = discriminator(images, training=True)
    fake_output = discriminator(generated_images, training=True)

    gen_loss = generator_loss(fake_output)
    disc_loss = discriminator_loss(real_output, fake_output)
    

    gradients_of_generator = gen_tape.gradient(\
        gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(\
        disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(
        gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(
        gradients_of_discriminator, 
        discriminator.trainable_variables))
  return gen_loss,disc_loss

# %%
def train(dataset, epochs):
  fixed_seed = np.random.normal(0, 1, (PREVIEW_ROWS * PREVIEW_COLS, 
                                       SEED_SIZE))
  start = time.time()

  for epoch in range(epochs):
    epoch_start = time.time()

    gen_loss_list = []
    disc_loss_list = []

    for image_batch in dataset:
      t = train_step(image_batch)
      gen_loss_list.append(t[0])
      disc_loss_list.append(t[1])

    g_loss = sum(gen_loss_list) / len(gen_loss_list)
    d_loss = sum(disc_loss_list) / len(disc_loss_list)

    epoch_elapsed = time.time()-epoch_start
    print (f'Epoch {epoch+1}, gen loss={g_loss},disc loss={d_loss},'\
           ' {hms_string(epoch_elapsed)}')
    save_images(epoch,fixed_seed)

  elapsed = time.time()-start
  print (f'Training time: {hms_string(elapsed)}')

# %%
train(train_dataset, EPOCHS)
# Out:
# Epoch 1, gen loss=2.611677646636963,disc loss=0.9840856790542603, {hms_string(epoch_elapsed)}
# Epoch 2, gen loss=3.174534320831299,disc loss=0.8668305277824402, {hms_string(epoch_elapsed)}
# Epoch 3, gen loss=3.5577447414398193,disc loss=0.8934954404830933, {hms_string(epoch_elapsed)}
# Epoch 4, gen loss=2.610339641571045,disc loss=0.9605109095573425, {hms_string(epoch_elapsed)}
# Epoch 5, gen loss=2.494249105453491,disc loss=0.9508686661720276, {hms_string(epoch_elapsed)}
# Epoch 6, gen loss=2.6593410968780518,disc loss=0.9413320422172546, {hms_string(epoch_elapsed)}
# Epoch 7, gen loss=2.6719655990600586,disc loss=0.9349657297134399, {hms_string(epoch_elapsed)}
# Epoch 8, gen loss=2.818942070007324,disc loss=0.7944884896278381, {hms_string(epoch_elapsed)}
# Epoch 9, gen loss=2.878962755203247,disc loss=0.7755535840988159, {hms_string(epoch_elapsed)}
# Epoch 10, gen loss=2.821288585662842,disc loss=0.7450348138809204, {hms_string(epoch_elapsed)}
# Epoch 11, gen loss=2.880307912826538,disc loss=0.7494762539863586, {hms_string(epoch_elapsed)}
# Epoch 12, gen loss=2.955662488937378,disc loss=0.6645763516426086, {hms_string(epoch_elapsed)}
# Epoch 13, gen loss=3.0630240440368652,disc loss=0.6821531057357788, {hms_string(epoch_elapsed)}
# Epoch 14, gen loss=3.1285171508789062,disc loss=0.6142972707748413, {hms_string(epoch_elapsed)}
# Epoch 15, gen loss=3.1562001705169678,disc loss=0.6485382318496704, {hms_string(epoch_elapsed)}
# Epoch 16, gen loss=3.168768882751465,disc loss=0.6506209373474121, {hms_string(epoch_elapsed)}
# Epoch 17, gen loss=3.2518439292907715,disc loss=0.672275722026825, {hms_string(epoch_elapsed)}
# Epoch 18, gen loss=3.222444772720337,disc loss=0.6136325001716614, {hms_string(epoch_elapsed)}
# Epoch 19, gen loss=3.3373491764068604,disc loss=0.6158142685890198, {hms_string(epoch_elapsed)}
# Epoch 20, gen loss=3.3693413734436035,disc loss=0.6418789625167847, {hms_string(epoch_elapsed)}
# Epoch 21, gen loss=3.434863328933716,disc loss=0.5435358881950378, {hms_string(epoch_elapsed)}
# Epoch 22, gen loss=3.4181149005889893,disc loss=0.5807062983512878, {hms_string(epoch_elapsed)}
# Epoch 23, gen loss=3.475945234298706,disc loss=0.5837874412536621, {hms_string(epoch_elapsed)}
# Epoch 24, gen loss=3.4970457553863525,disc loss=0.5596336722373962, {hms_string(epoch_elapsed)}
# Epoch 25, gen loss=3.520892381668091,disc loss=0.5526973605155945, {hms_string(epoch_elapsed)}
# Epoch 26, gen loss=3.5995092391967773,disc loss=0.5613505244255066, {hms_string(epoch_elapsed)}
# Epoch 27, gen loss=3.650272846221924,disc loss=0.514712929725647, {hms_string(epoch_elapsed)}
# Epoch 28, gen loss=3.6801838874816895,disc loss=0.5313366651535034, {hms_string(epoch_elapsed)}
# Epoch 29, gen loss=3.7883341312408447,disc loss=0.47430911660194397, {hms_string(epoch_elapsed)}
# Epoch 30, gen loss=3.843398094177246,disc loss=0.49902936816215515, {hms_string(epoch_elapsed)}
# Epoch 31, gen loss=3.8846356868743896,disc loss=0.4940619468688965, {hms_string(epoch_elapsed)}
# Epoch 32, gen loss=4.021421909332275,disc loss=0.49516749382019043, {hms_string(epoch_elapsed)}
# Epoch 33, gen loss=3.962232828140259,disc loss=0.48313915729522705, {hms_string(epoch_elapsed)}
# Epoch 34, gen loss=3.980231285095215,disc loss=0.5019792914390564, {hms_string(epoch_elapsed)}
# Epoch 35, gen loss=4.114156246185303,disc loss=0.49780625104904175, {hms_string(epoch_elapsed)}
# Epoch 36, gen loss=4.163636207580566,disc loss=0.4940021336078644, {hms_string(epoch_elapsed)}
# Epoch 37, gen loss=4.093958854675293,disc loss=0.46305349469184875, {hms_string(epoch_elapsed)}
# Epoch 38, gen loss=4.125570774078369,disc loss=0.4252206087112427, {hms_string(epoch_elapsed)}
# Epoch 39, gen loss=4.2126994132995605,disc loss=0.45625972747802734, {hms_string(epoch_elapsed)}
# Epoch 40, gen loss=4.248249530792236,disc loss=0.42765483260154724, {hms_string(epoch_elapsed)}
# Epoch 41, gen loss=4.313508033752441,disc loss=0.4206485152244568, {hms_string(epoch_elapsed)}
# Epoch 42, gen loss=4.430812358856201,disc loss=0.42294979095458984, {hms_string(epoch_elapsed)}
# Epoch 43, gen loss=4.435640811920166,disc loss=0.4296998977661133, {hms_string(epoch_elapsed)}
# Epoch 44, gen loss=4.420064449310303,disc loss=0.38756898045539856, {hms_string(epoch_elapsed)}
# Epoch 45, gen loss=4.53998327255249,disc loss=0.4149356484413147, {hms_string(epoch_elapsed)}
# Epoch 46, gen loss=4.645204544067383,disc loss=0.4000805914402008, {hms_string(epoch_elapsed)}
# Epoch 47, gen loss=4.573328495025635,disc loss=0.40958383679389954, {hms_string(epoch_elapsed)}
# Epoch 48, gen loss=4.664524555206299,disc loss=0.3968760371208191, {hms_string(epoch_elapsed)}
# Epoch 49, gen loss=4.640194892883301,disc loss=0.405970960855484, {hms_string(epoch_elapsed)}
# Epoch 50, gen loss=4.748480796813965,disc loss=0.41179782152175903, {hms_string(epoch_elapsed)}
# Epoch 51, gen loss=4.670373439788818,disc loss=0.3805806040763855, {hms_string(epoch_elapsed)}
# Epoch 52, gen loss=4.741764545440674,disc loss=0.3721714913845062, {hms_string(epoch_elapsed)}
# Epoch 53, gen loss=4.851099014282227,disc loss=0.3994162380695343, {hms_string(epoch_elapsed)}
# Epoch 54, gen loss=4.9493327140808105,disc loss=0.35068678855895996, {hms_string(epoch_elapsed)}
# Epoch 55, gen loss=4.956348896026611,disc loss=0.3701292872428894, {hms_string(epoch_elapsed)}
# Epoch 56, gen loss=5.090449810028076,disc loss=0.35512131452560425, {hms_string(epoch_elapsed)}
# Epoch 57, gen loss=5.01199197769165,disc loss=0.3316272497177124, {hms_string(epoch_elapsed)}
# Epoch 58, gen loss=5.061551570892334,disc loss=0.35043999552726746, {hms_string(epoch_elapsed)}
# Epoch 59, gen loss=5.060303688049316,disc loss=0.3342726528644562, {hms_string(epoch_elapsed)}
# Epoch 60, gen loss=5.11403226852417,disc loss=0.32696229219436646, {hms_string(epoch_elapsed)}
# Epoch 61, gen loss=5.217918872833252,disc loss=0.3447892367839813, {hms_string(epoch_elapsed)}
# Epoch 62, gen loss=5.209484100341797,disc loss=0.3255878984928131, {hms_string(epoch_elapsed)}
# Epoch 63, gen loss=5.294583797454834,disc loss=0.2807469666004181, {hms_string(epoch_elapsed)}
# Epoch 64, gen loss=5.405978679656982,disc loss=0.377734899520874, {hms_string(epoch_elapsed)}
# Epoch 65, gen loss=5.373912334442139,disc loss=0.32154595851898193, {hms_string(epoch_elapsed)}
# Epoch 66, gen loss=5.336811065673828,disc loss=0.3263489007949829, {hms_string(epoch_elapsed)}
# Epoch 67, gen loss=5.500609397888184,disc loss=0.30560675263404846, {hms_string(epoch_elapsed)}
# Epoch 68, gen loss=5.40779972076416,disc loss=0.34405550360679626, {hms_string(epoch_elapsed)}
# Epoch 69, gen loss=5.517364978790283,disc loss=0.2593216001987457, {hms_string(epoch_elapsed)}
# Epoch 70, gen loss=5.575254440307617,disc loss=0.3122529685497284, {hms_string(epoch_elapsed)}
# Epoch 71, gen loss=5.711040019989014,disc loss=0.2998233437538147, {hms_string(epoch_elapsed)}
# Epoch 72, gen loss=5.7446088790893555,disc loss=0.27746856212615967, {hms_string(epoch_elapsed)}
# Epoch 73, gen loss=5.691219329833984,disc loss=0.31865760684013367, {hms_string(epoch_elapsed)}
# Epoch 74, gen loss=5.799492359161377,disc loss=0.28576692938804626, {hms_string(epoch_elapsed)}
# Epoch 75, gen loss=5.809467792510986,disc loss=0.28460124135017395, {hms_string(epoch_elapsed)}
# Epoch 76, gen loss=5.735678672790527,disc loss=0.28297263383865356, {hms_string(epoch_elapsed)}
# Epoch 77, gen loss=5.814232349395752,disc loss=0.32565033435821533, {hms_string(epoch_elapsed)}
# Epoch 78, gen loss=5.839256763458252,disc loss=0.24692191183567047, {hms_string(epoch_elapsed)}
# Epoch 79, gen loss=5.958425998687744,disc loss=0.272816926240921, {hms_string(epoch_elapsed)}
# Epoch 80, gen loss=5.923293113708496,disc loss=0.27842167019844055, {hms_string(epoch_elapsed)}
# Epoch 81, gen loss=6.102149963378906,disc loss=0.2934189736843109, {hms_string(epoch_elapsed)}
# Epoch 82, gen loss=6.009753227233887,disc loss=0.2917294204235077, {hms_string(epoch_elapsed)}
# Epoch 83, gen loss=6.131738662719727,disc loss=0.22632215917110443, {hms_string(epoch_elapsed)}
# Epoch 84, gen loss=6.052621364593506,disc loss=0.3166161775588989, {hms_string(epoch_elapsed)}
# Epoch 85, gen loss=6.201848030090332,disc loss=0.2552350163459778, {hms_string(epoch_elapsed)}
# Epoch 86, gen loss=6.1230998039245605,disc loss=0.2386915385723114, {hms_string(epoch_elapsed)}
# Epoch 87, gen loss=6.200693607330322,disc loss=0.2769342064857483, {hms_string(epoch_elapsed)}
# Epoch 88, gen loss=6.3992695808410645,disc loss=0.2734905481338501, {hms_string(epoch_elapsed)}
# Epoch 89, gen loss=6.430008411407471,disc loss=0.2450304478406906, {hms_string(epoch_elapsed)}
# Epoch 90, gen loss=6.384413242340088,disc loss=0.25909724831581116, {hms_string(epoch_elapsed)}
# Epoch 91, gen loss=6.415861129760742,disc loss=0.27249619364738464, {hms_string(epoch_elapsed)}
# Epoch 92, gen loss=6.486494541168213,disc loss=0.24618618190288544, {hms_string(epoch_elapsed)}
# Epoch 93, gen loss=6.570864677429199,disc loss=0.239254429936409, {hms_string(epoch_elapsed)}
# Epoch 94, gen loss=6.458547592163086,disc loss=0.23981694877147675, {hms_string(epoch_elapsed)}
# Epoch 95, gen loss=6.540566921234131,disc loss=0.222373828291893, {hms_string(epoch_elapsed)}
# Epoch 96, gen loss=6.644686222076416,disc loss=0.2838170826435089, {hms_string(epoch_elapsed)}
# Epoch 97, gen loss=6.633579730987549,disc loss=0.2278948277235031, {hms_string(epoch_elapsed)}
# Epoch 98, gen loss=6.697045803070068,disc loss=0.19216200709342957, {hms_string(epoch_elapsed)}
# Epoch 99, gen loss=6.94487190246582,disc loss=0.2415403127670288, {hms_string(epoch_elapsed)}
# Epoch 100, gen loss=6.842810153961182,disc loss=0.23897813260555267, {hms_string(epoch_elapsed)}
# Epoch 101, gen loss=6.9021711349487305,disc loss=0.18464668095111847, {hms_string(epoch_elapsed)}
# Epoch 102, gen loss=6.770157337188721,disc loss=0.26378732919692993, {hms_string(epoch_elapsed)}
# Epoch 103, gen loss=6.860538959503174,disc loss=0.23162564635276794, {hms_string(epoch_elapsed)}
# Epoch 104, gen loss=6.988658905029297,disc loss=0.23372957110404968, {hms_string(epoch_elapsed)}
# Epoch 105, gen loss=6.884885311126709,disc loss=0.19057007133960724, {hms_string(epoch_elapsed)}
# Epoch 106, gen loss=7.026098728179932,disc loss=0.22012223303318024, {hms_string(epoch_elapsed)}
# Epoch 107, gen loss=6.924626350402832,disc loss=0.2582639157772064, {hms_string(epoch_elapsed)}
# Epoch 108, gen loss=7.010500431060791,disc loss=0.2035389244556427, {hms_string(epoch_elapsed)}
# Epoch 109, gen loss=7.200930595397949,disc loss=0.2573808431625366, {hms_string(epoch_elapsed)}
# Epoch 110, gen loss=7.075464248657227,disc loss=0.19105203449726105, {hms_string(epoch_elapsed)}
# Epoch 111, gen loss=7.218639373779297,disc loss=0.24729737639427185, {hms_string(epoch_elapsed)}
# Epoch 112, gen loss=7.087437152862549,disc loss=0.1866595447063446, {hms_string(epoch_elapsed)}
# Epoch 113, gen loss=7.204291343688965,disc loss=0.24022948741912842, {hms_string(epoch_elapsed)}
# Epoch 114, gen loss=7.177934646606445,disc loss=0.1686350703239441, {hms_string(epoch_elapsed)}
# Epoch 115, gen loss=7.236988544464111,disc loss=0.2599446773529053, {hms_string(epoch_elapsed)}
# Epoch 116, gen loss=7.331687927246094,disc loss=0.211374893784523, {hms_string(epoch_elapsed)}
# Epoch 117, gen loss=7.447934627532959,disc loss=0.18981939554214478, {hms_string(epoch_elapsed)}
# Epoch 118, gen loss=7.407654285430908,disc loss=0.14935731887817383, {hms_string(epoch_elapsed)}
# Epoch 119, gen loss=7.487916946411133,disc loss=0.19669058918952942, {hms_string(epoch_elapsed)}
# Epoch 120, gen loss=7.412008285522461,disc loss=0.19558411836624146, {hms_string(epoch_elapsed)}
# Epoch 121, gen loss=7.676258563995361,disc loss=0.2374849021434784, {hms_string(epoch_elapsed)}
# Epoch 122, gen loss=7.515903949737549,disc loss=0.21105027198791504, {hms_string(epoch_elapsed)}
# Epoch 123, gen loss=7.7140092849731445,disc loss=0.18872815370559692, {hms_string(epoch_elapsed)}
# Epoch 124, gen loss=7.572808265686035,disc loss=0.19959934055805206, {hms_string(epoch_elapsed)}
# Epoch 125, gen loss=7.562585830688477,disc loss=0.2194051593542099, {hms_string(epoch_elapsed)}
# Epoch 126, gen loss=7.551445960998535,disc loss=0.16952477395534515, {hms_string(epoch_elapsed)}
# Epoch 127, gen loss=7.551968097686768,disc loss=0.1769106239080429, {hms_string(epoch_elapsed)}
# Epoch 128, gen loss=7.638883113861084,disc loss=0.23196212947368622, {hms_string(epoch_elapsed)}
# Epoch 129, gen loss=7.680250644683838,disc loss=0.1847573220729828, {hms_string(epoch_elapsed)}
# Epoch 130, gen loss=7.6674723625183105,disc loss=0.2454930692911148, {hms_string(epoch_elapsed)}
# Epoch 131, gen loss=7.691975116729736,disc loss=0.20039014518260956, {hms_string(epoch_elapsed)}
# Epoch 132, gen loss=7.673503875732422,disc loss=0.19303174316883087, {hms_string(epoch_elapsed)}
# Epoch 133, gen loss=7.891174793243408,disc loss=0.20804661512374878, {hms_string(epoch_elapsed)}
# Epoch 134, gen loss=7.910835266113281,disc loss=0.16303762793540955, {hms_string(epoch_elapsed)}
# Epoch 135, gen loss=7.887703895568848,disc loss=0.14878365397453308, {hms_string(epoch_elapsed)}
# Epoch 136, gen loss=7.9537506103515625,disc loss=0.2019893378019333, {hms_string(epoch_elapsed)}
# Epoch 137, gen loss=8.065872192382812,disc loss=0.22189389169216156, {hms_string(epoch_elapsed)}
# Epoch 138, gen loss=8.040300369262695,disc loss=0.157259002327919, {hms_string(epoch_elapsed)}
# Epoch 139, gen loss=7.9814581871032715,disc loss=0.19007748365402222, {hms_string(epoch_elapsed)}
# Epoch 140, gen loss=7.954578876495361,disc loss=0.19591093063354492, {hms_string(epoch_elapsed)}
# Epoch 141, gen loss=8.084039688110352,disc loss=0.13788969814777374, {hms_string(epoch_elapsed)}
# Epoch 142, gen loss=7.988631248474121,disc loss=0.2932097017765045, {hms_string(epoch_elapsed)}
# Epoch 143, gen loss=8.073103904724121,disc loss=0.18028445541858673, {hms_string(epoch_elapsed)}
# Epoch 144, gen loss=8.160161018371582,disc loss=0.18509754538536072, {hms_string(epoch_elapsed)}
# Epoch 145, gen loss=8.164565086364746,disc loss=0.13713020086288452, {hms_string(epoch_elapsed)}
# Epoch 146, gen loss=8.184599876403809,disc loss=0.18972918391227722, {hms_string(epoch_elapsed)}
# Epoch 147, gen loss=8.318610191345215,disc loss=0.16595551371574402, {hms_string(epoch_elapsed)}
# Epoch 148, gen loss=8.128628730773926,disc loss=0.17123626172542572, {hms_string(epoch_elapsed)}
# Epoch 149, gen loss=8.128650665283203,disc loss=0.2374156415462494, {hms_string(epoch_elapsed)}
# Epoch 150, gen loss=8.193620681762695,disc loss=0.19062133133411407, {hms_string(epoch_elapsed)}
# Epoch 151, gen loss=8.33161735534668,disc loss=0.16538947820663452, {hms_string(epoch_elapsed)}
# Epoch 152, gen loss=8.28601360321045,disc loss=0.16253067553043365, {hms_string(epoch_elapsed)}
# Epoch 153, gen loss=8.42680549621582,disc loss=0.17329595983028412, {hms_string(epoch_elapsed)}
# Epoch 154, gen loss=8.361573219299316,disc loss=0.16957934200763702, {hms_string(epoch_elapsed)}
# Epoch 155, gen loss=8.39022445678711,disc loss=0.15111574530601501, {hms_string(epoch_elapsed)}
# Epoch 156, gen loss=8.444007873535156,disc loss=0.1523520052433014, {hms_string(epoch_elapsed)}
# Epoch 157, gen loss=8.556086540222168,disc loss=0.22167859971523285, {hms_string(epoch_elapsed)}
# Epoch 158, gen loss=8.482528686523438,disc loss=0.19499571621418, {hms_string(epoch_elapsed)}
# Epoch 159, gen loss=8.7641019821167,disc loss=0.18575046956539154, {hms_string(epoch_elapsed)}
# Epoch 160, gen loss=8.493189811706543,disc loss=0.1429757922887802, {hms_string(epoch_elapsed)}
# Epoch 161, gen loss=8.417869567871094,disc loss=0.15270687639713287, {hms_string(epoch_elapsed)}
# Epoch 162, gen loss=8.582864761352539,disc loss=0.21470502018928528, {hms_string(epoch_elapsed)}
# Epoch 163, gen loss=8.796157836914062,disc loss=0.1423182487487793, {hms_string(epoch_elapsed)}
# Epoch 164, gen loss=8.58557415008545,disc loss=0.16239167749881744, {hms_string(epoch_elapsed)}
# Epoch 165, gen loss=8.771309852600098,disc loss=0.17217335104942322, {hms_string(epoch_elapsed)}
# Epoch 166, gen loss=8.628323554992676,disc loss=0.17656245827674866, {hms_string(epoch_elapsed)}
# Epoch 167, gen loss=8.647621154785156,disc loss=0.18002550303936005, {hms_string(epoch_elapsed)}
# Epoch 168, gen loss=8.722555160522461,disc loss=0.13915273547172546, {hms_string(epoch_elapsed)}
# Epoch 169, gen loss=8.669121742248535,disc loss=0.21408244967460632, {hms_string(epoch_elapsed)}
# Epoch 170, gen loss=8.658979415893555,disc loss=0.1798376888036728, {hms_string(epoch_elapsed)}
# Epoch 171, gen loss=8.756207466125488,disc loss=0.16634026169776917, {hms_string(epoch_elapsed)}
# Epoch 172, gen loss=8.823014259338379,disc loss=0.19809186458587646, {hms_string(epoch_elapsed)}
# Epoch 173, gen loss=8.781868934631348,disc loss=0.17866866290569305, {hms_string(epoch_elapsed)}
# Epoch 174, gen loss=8.92713737487793,disc loss=0.1306036412715912, {hms_string(epoch_elapsed)}
# Epoch 175, gen loss=8.865435600280762,disc loss=0.16120405495166779, {hms_string(epoch_elapsed)}
# Epoch 176, gen loss=8.63304328918457,disc loss=0.22450417280197144, {hms_string(epoch_elapsed)}
# Epoch 177, gen loss=8.891717910766602,disc loss=0.11655417084693909, {hms_string(epoch_elapsed)}
# Epoch 178, gen loss=9.158854484558105,disc loss=0.21542507410049438, {hms_string(epoch_elapsed)}
# Epoch 179, gen loss=8.816384315490723,disc loss=0.14496639370918274, {hms_string(epoch_elapsed)}
# Epoch 180, gen loss=9.089798927307129,disc loss=0.14741741120815277, {hms_string(epoch_elapsed)}
# Epoch 181, gen loss=9.037991523742676,disc loss=0.14171381294727325, {hms_string(epoch_elapsed)}
# Epoch 182, gen loss=9.18033218383789,disc loss=0.13528290390968323, {hms_string(epoch_elapsed)}
# Epoch 183, gen loss=9.062284469604492,disc loss=0.17875538766384125, {hms_string(epoch_elapsed)}
# Epoch 184, gen loss=9.096147537231445,disc loss=0.1369238942861557, {hms_string(epoch_elapsed)}
# Epoch 185, gen loss=9.083808898925781,disc loss=0.16492430865764618, {hms_string(epoch_elapsed)}
# Epoch 186, gen loss=8.963735580444336,disc loss=0.1981225609779358, {hms_string(epoch_elapsed)}
# Epoch 187, gen loss=9.019832611083984,disc loss=0.13540028035640717, {hms_string(epoch_elapsed)}
# Epoch 188, gen loss=9.03500747680664,disc loss=0.13024091720581055, {hms_string(epoch_elapsed)}
# Epoch 189, gen loss=9.309064865112305,disc loss=0.1494450718164444, {hms_string(epoch_elapsed)}
# Epoch 190, gen loss=9.119786262512207,disc loss=0.29341942071914673, {hms_string(epoch_elapsed)}
# Epoch 191, gen loss=8.99277400970459,disc loss=0.13555744290351868, {hms_string(epoch_elapsed)}
# Epoch 192, gen loss=9.124244689941406,disc loss=0.15886925160884857, {hms_string(epoch_elapsed)}
# Epoch 193, gen loss=9.270452499389648,disc loss=0.12296276539564133, {hms_string(epoch_elapsed)}
# Epoch 194, gen loss=9.40758228302002,disc loss=0.1648995280265808, {hms_string(epoch_elapsed)}
# Epoch 195, gen loss=9.082658767700195,disc loss=0.13844303786754608, {hms_string(epoch_elapsed)}
# Epoch 196, gen loss=9.25234603881836,disc loss=0.22423326969146729, {hms_string(epoch_elapsed)}
# Epoch 197, gen loss=9.301359176635742,disc loss=0.1520499438047409, {hms_string(epoch_elapsed)}
# Epoch 198, gen loss=9.23238468170166,disc loss=0.14516565203666687, {hms_string(epoch_elapsed)}
# Epoch 199, gen loss=9.266722679138184,disc loss=0.15613707900047302, {hms_string(epoch_elapsed)}
# Epoch 200, gen loss=9.36190128326416,disc loss=0.12126973271369934, {hms_string(epoch_elapsed)}
# Epoch 201, gen loss=9.346749305725098,disc loss=0.17841720581054688, {hms_string(epoch_elapsed)}
# Epoch 202, gen loss=9.28554916381836,disc loss=0.09901706874370575, {hms_string(epoch_elapsed)}
# Epoch 203, gen loss=9.524967193603516,disc loss=0.12876561284065247, {hms_string(epoch_elapsed)}
# Epoch 204, gen loss=9.371089935302734,disc loss=0.21902689337730408, {hms_string(epoch_elapsed)}
# Epoch 205, gen loss=9.426719665527344,disc loss=0.16432128846645355, {hms_string(epoch_elapsed)}
# Epoch 206, gen loss=9.536392211914062,disc loss=0.14346279203891754, {hms_string(epoch_elapsed)}
# Epoch 207, gen loss=9.549088478088379,disc loss=0.12991559505462646, {hms_string(epoch_elapsed)}
# Epoch 208, gen loss=9.384060859680176,disc loss=0.17834964394569397, {hms_string(epoch_elapsed)}
# Epoch 209, gen loss=9.532997131347656,disc loss=0.209883913397789, {hms_string(epoch_elapsed)}
# Epoch 210, gen loss=9.672718048095703,disc loss=0.11978838592767715, {hms_string(epoch_elapsed)}
# Epoch 211, gen loss=9.650718688964844,disc loss=0.12922820448875427, {hms_string(epoch_elapsed)}
# Epoch 212, gen loss=9.527688026428223,disc loss=0.11631955206394196, {hms_string(epoch_elapsed)}
# Epoch 213, gen loss=9.47818374633789,disc loss=0.16371044516563416, {hms_string(epoch_elapsed)}
# Epoch 214, gen loss=9.274430274963379,disc loss=0.18362580239772797, {hms_string(epoch_elapsed)}
# Epoch 215, gen loss=9.504402160644531,disc loss=0.13461779057979584, {hms_string(epoch_elapsed)}
# Epoch 216, gen loss=9.677050590515137,disc loss=0.11601568013429642, {hms_string(epoch_elapsed)}
# Epoch 217, gen loss=9.83292293548584,disc loss=0.1484702229499817, {hms_string(epoch_elapsed)}
# Epoch 218, gen loss=9.745940208435059,disc loss=0.16502046585083008, {hms_string(epoch_elapsed)}
# Epoch 219, gen loss=9.72807502746582,disc loss=0.13787433505058289, {hms_string(epoch_elapsed)}
# Epoch 220, gen loss=9.847722053527832,disc loss=0.13551749289035797, {hms_string(epoch_elapsed)}
# Epoch 221, gen loss=9.775005340576172,disc loss=0.14130757749080658, {hms_string(epoch_elapsed)}
# Epoch 222, gen loss=9.81149673461914,disc loss=0.12152187526226044, {hms_string(epoch_elapsed)}
# Epoch 223, gen loss=9.7912015914917,disc loss=0.14119219779968262, {hms_string(epoch_elapsed)}
# Epoch 224, gen loss=9.854598045349121,disc loss=0.16323426365852356, {hms_string(epoch_elapsed)}
# Epoch 225, gen loss=9.819210052490234,disc loss=0.10894978791475296, {hms_string(epoch_elapsed)}
# Epoch 226, gen loss=9.753809928894043,disc loss=0.13039347529411316, {hms_string(epoch_elapsed)}
# Epoch 227, gen loss=9.816105842590332,disc loss=0.10005033016204834, {hms_string(epoch_elapsed)}
# Epoch 228, gen loss=9.83812427520752,disc loss=0.14977380633354187, {hms_string(epoch_elapsed)}
# Epoch 229, gen loss=9.836263656616211,disc loss=0.21821676194667816, {hms_string(epoch_elapsed)}
# Epoch 230, gen loss=9.718497276306152,disc loss=0.14874449372291565, {hms_string(epoch_elapsed)}
# Epoch 231, gen loss=10.056977272033691,disc loss=0.10473967343568802, {hms_string(epoch_elapsed)}
# Epoch 232, gen loss=10.10986614227295,disc loss=0.12254240363836288, {hms_string(epoch_elapsed)}
# Epoch 233, gen loss=10.10304069519043,disc loss=0.10526103526353836, {hms_string(epoch_elapsed)}
# Epoch 234, gen loss=10.1315279006958,disc loss=0.12424346059560776, {hms_string(epoch_elapsed)}
# Epoch 235, gen loss=10.050594329833984,disc loss=0.17816875874996185, {hms_string(epoch_elapsed)}
# Epoch 236, gen loss=10.096430778503418,disc loss=0.20438167452812195, {hms_string(epoch_elapsed)}
# Epoch 237, gen loss=9.79297161102295,disc loss=0.14095087349414825, {hms_string(epoch_elapsed)}
# Epoch 238, gen loss=10.103719711303711,disc loss=0.10627992451190948, {hms_string(epoch_elapsed)}
# Epoch 239, gen loss=9.869935035705566,disc loss=0.1302998811006546, {hms_string(epoch_elapsed)}
# Epoch 240, gen loss=10.149295806884766,disc loss=0.14873632788658142, {hms_string(epoch_elapsed)}
# Epoch 241, gen loss=10.16028881072998,disc loss=0.1104012206196785, {hms_string(epoch_elapsed)}
# Epoch 242, gen loss=10.096023559570312,disc loss=0.17742057144641876, {hms_string(epoch_elapsed)}
# Epoch 243, gen loss=10.141590118408203,disc loss=0.14150792360305786, {hms_string(epoch_elapsed)}
# Epoch 244, gen loss=10.084147453308105,disc loss=0.1215205043554306, {hms_string(epoch_elapsed)}
# Epoch 245, gen loss=10.065927505493164,disc loss=0.1177939772605896, {hms_string(epoch_elapsed)}
# Epoch 246, gen loss=10.111254692077637,disc loss=0.1413268744945526, {hms_string(epoch_elapsed)}
# Epoch 247, gen loss=9.930883407592773,disc loss=0.20196710526943207, {hms_string(epoch_elapsed)}
# Epoch 248, gen loss=10.262964248657227,disc loss=0.14585429430007935, {hms_string(epoch_elapsed)}
# Epoch 249, gen loss=10.20805835723877,disc loss=0.14502538740634918, {hms_string(epoch_elapsed)}
# Epoch 250, gen loss=10.291933059692383,disc loss=0.08457774668931961, {hms_string(epoch_elapsed)}
# Epoch 251, gen loss=10.359062194824219,disc loss=0.14234422147274017, {hms_string(epoch_elapsed)}
# Epoch 252, gen loss=10.233935356140137,disc loss=0.12572798132896423, {hms_string(epoch_elapsed)}
# Epoch 253, gen loss=10.208038330078125,disc loss=0.10351485759019852, {hms_string(epoch_elapsed)}
# Epoch 254, gen loss=10.46904182434082,disc loss=0.11413296312093735, {hms_string(epoch_elapsed)}
# Epoch 255, gen loss=10.448583602905273,disc loss=0.14211787283420563, {hms_string(epoch_elapsed)}
# Epoch 256, gen loss=10.331306457519531,disc loss=0.10049370676279068, {hms_string(epoch_elapsed)}
# Epoch 257, gen loss=10.480940818786621,disc loss=0.11341775953769684, {hms_string(epoch_elapsed)}
# Epoch 258, gen loss=10.49526309967041,disc loss=0.10677357763051987, {hms_string(epoch_elapsed)}
# Epoch 259, gen loss=10.65503215789795,disc loss=0.19578911364078522, {hms_string(epoch_elapsed)}
# Epoch 260, gen loss=10.391263008117676,disc loss=0.18403039872646332, {hms_string(epoch_elapsed)}
# Epoch 261, gen loss=10.45678997039795,disc loss=0.13390997052192688, {hms_string(epoch_elapsed)}
# Epoch 262, gen loss=10.469655990600586,disc loss=0.12274233251810074, {hms_string(epoch_elapsed)}
# Epoch 263, gen loss=10.416942596435547,disc loss=0.15185587108135223, {hms_string(epoch_elapsed)}
# Epoch 264, gen loss=10.662720680236816,disc loss=0.08610965311527252, {hms_string(epoch_elapsed)}
# Epoch 265, gen loss=10.653592109680176,disc loss=0.16505780816078186, {hms_string(epoch_elapsed)}
# Epoch 266, gen loss=10.471295356750488,disc loss=0.175442636013031, {hms_string(epoch_elapsed)}
# Epoch 267, gen loss=10.442919731140137,disc loss=0.08705443888902664, {hms_string(epoch_elapsed)}
# Epoch 268, gen loss=10.65876579284668,disc loss=0.10717486590147018, {hms_string(epoch_elapsed)}
# Epoch 269, gen loss=10.689249038696289,disc loss=0.1068413108587265, {hms_string(epoch_elapsed)}
# Epoch 270, gen loss=10.748737335205078,disc loss=0.1196306049823761, {hms_string(epoch_elapsed)}
# Epoch 271, gen loss=10.71251106262207,disc loss=0.10890194773674011, {hms_string(epoch_elapsed)}
# Epoch 272, gen loss=10.72115707397461,disc loss=0.13375310599803925, {hms_string(epoch_elapsed)}
# Epoch 273, gen loss=10.747645378112793,disc loss=0.10755497962236404, {hms_string(epoch_elapsed)}
# Epoch 274, gen loss=10.40458869934082,disc loss=0.16151763498783112, {hms_string(epoch_elapsed)}
# Epoch 275, gen loss=10.67674446105957,disc loss=0.1495232731103897, {hms_string(epoch_elapsed)}
# Epoch 276, gen loss=10.759427070617676,disc loss=0.1305459886789322, {hms_string(epoch_elapsed)}
# Epoch 277, gen loss=10.838066101074219,disc loss=0.09281540662050247, {hms_string(epoch_elapsed)}
# Epoch 278, gen loss=10.793238639831543,disc loss=0.12992601096630096, {hms_string(epoch_elapsed)}
# Epoch 279, gen loss=10.54443073272705,disc loss=0.14455293118953705, {hms_string(epoch_elapsed)}
# Epoch 280, gen loss=10.856931686401367,disc loss=0.08180468529462814, {hms_string(epoch_elapsed)}
# Epoch 281, gen loss=10.850439071655273,disc loss=0.1505262851715088, {hms_string(epoch_elapsed)}
# Epoch 282, gen loss=10.810721397399902,disc loss=0.09363003820180893, {hms_string(epoch_elapsed)}
# Epoch 283, gen loss=10.705584526062012,disc loss=0.1809791624546051, {hms_string(epoch_elapsed)}
# Epoch 284, gen loss=10.606646537780762,disc loss=0.16130760312080383, {hms_string(epoch_elapsed)}
# Epoch 285, gen loss=10.965590476989746,disc loss=0.09912654012441635, {hms_string(epoch_elapsed)}
# Epoch 286, gen loss=10.725001335144043,disc loss=0.10642103105783463, {hms_string(epoch_elapsed)}
# Epoch 287, gen loss=10.870383262634277,disc loss=0.10931693017482758, {hms_string(epoch_elapsed)}
# Epoch 288, gen loss=10.941615104675293,disc loss=0.1266193389892578, {hms_string(epoch_elapsed)}
# Epoch 289, gen loss=10.89033031463623,disc loss=0.18463216722011566, {hms_string(epoch_elapsed)}
# Epoch 290, gen loss=10.9111909866333,disc loss=0.08349233865737915, {hms_string(epoch_elapsed)}
# Epoch 291, gen loss=10.982390403747559,disc loss=0.11707944422960281, {hms_string(epoch_elapsed)}
# Epoch 292, gen loss=10.825668334960938,disc loss=0.11067109555006027, {hms_string(epoch_elapsed)}
# Epoch 293, gen loss=10.863541603088379,disc loss=0.17324382066726685, {hms_string(epoch_elapsed)}
# Epoch 294, gen loss=10.847638130187988,disc loss=0.1005401760339737, {hms_string(epoch_elapsed)}
# Epoch 295, gen loss=11.125004768371582,disc loss=0.10809570550918579, {hms_string(epoch_elapsed)}
# Epoch 296, gen loss=11.118553161621094,disc loss=0.0925048217177391, {hms_string(epoch_elapsed)}
# Epoch 297, gen loss=11.071391105651855,disc loss=0.10709511488676071, {hms_string(epoch_elapsed)}
# Epoch 298, gen loss=11.391362190246582,disc loss=0.1522221714258194, {hms_string(epoch_elapsed)}
# Epoch 299, gen loss=10.920098304748535,disc loss=0.13065533339977264, {hms_string(epoch_elapsed)}
# Epoch 300, gen loss=10.91038990020752,disc loss=0.09749563038349152, {hms_string(epoch_elapsed)}
# Epoch 301, gen loss=11.029895782470703,disc loss=0.07565844804048538, {hms_string(epoch_elapsed)}
# Epoch 302, gen loss=11.181936264038086,disc loss=0.10048076510429382, {hms_string(epoch_elapsed)}
# Epoch 303, gen loss=10.984169006347656,disc loss=0.13161829113960266, {hms_string(epoch_elapsed)}
# Epoch 304, gen loss=10.822277069091797,disc loss=0.1153629869222641, {hms_string(epoch_elapsed)}
# Epoch 305, gen loss=11.613580703735352,disc loss=0.11449825763702393, {hms_string(epoch_elapsed)}
# Epoch 306, gen loss=11.05589771270752,disc loss=0.10650444030761719, {hms_string(epoch_elapsed)}
# Epoch 307, gen loss=11.134498596191406,disc loss=0.2013019174337387, {hms_string(epoch_elapsed)}
# Epoch 308, gen loss=11.211160659790039,disc loss=0.1381203830242157, {hms_string(epoch_elapsed)}
# Epoch 309, gen loss=11.145795822143555,disc loss=0.09317705035209656, {hms_string(epoch_elapsed)}
# Epoch 310, gen loss=11.394981384277344,disc loss=0.14096802473068237, {hms_string(epoch_elapsed)}
# Epoch 311, gen loss=11.238279342651367,disc loss=0.14065998792648315, {hms_string(epoch_elapsed)}
# Epoch 312, gen loss=11.13435173034668,disc loss=0.09470326453447342, {hms_string(epoch_elapsed)}
# Epoch 313, gen loss=11.274775505065918,disc loss=0.10176071524620056, {hms_string(epoch_elapsed)}
# Epoch 314, gen loss=11.115031242370605,disc loss=0.09644400328397751, {hms_string(epoch_elapsed)}
# Epoch 315, gen loss=11.373275756835938,disc loss=0.09715037047863007, {hms_string(epoch_elapsed)}
# Epoch 316, gen loss=11.241705894470215,disc loss=0.09444170445203781, {hms_string(epoch_elapsed)}
# Epoch 317, gen loss=11.209617614746094,disc loss=0.16514205932617188, {hms_string(epoch_elapsed)}
# Epoch 318, gen loss=11.157286643981934,disc loss=0.11657729744911194, {hms_string(epoch_elapsed)}
# Epoch 319, gen loss=11.56800365447998,disc loss=0.09922000765800476, {hms_string(epoch_elapsed)}
# Epoch 320, gen loss=11.491792678833008,disc loss=0.09348715096712112, {hms_string(epoch_elapsed)}
# Epoch 321, gen loss=11.45993423461914,disc loss=0.07681494206190109, {hms_string(epoch_elapsed)}
# Epoch 322, gen loss=11.266379356384277,disc loss=0.12376289814710617, {hms_string(epoch_elapsed)}
# Epoch 323, gen loss=11.48106861114502,disc loss=0.12184927612543106, {hms_string(epoch_elapsed)}
# Epoch 324, gen loss=11.411736488342285,disc loss=0.14363741874694824, {hms_string(epoch_elapsed)}
# Epoch 325, gen loss=11.62679386138916,disc loss=0.19104650616645813, {hms_string(epoch_elapsed)}
# Epoch 326, gen loss=11.437212944030762,disc loss=0.1126374825835228, {hms_string(epoch_elapsed)}
# Epoch 327, gen loss=11.531903266906738,disc loss=0.09759994596242905, {hms_string(epoch_elapsed)}
# Epoch 328, gen loss=11.4010591506958,disc loss=0.09263361245393753, {hms_string(epoch_elapsed)}
# Epoch 329, gen loss=11.547002792358398,disc loss=0.09335029870271683, {hms_string(epoch_elapsed)}
# Epoch 330, gen loss=11.605979919433594,disc loss=0.10084173083305359, {hms_string(epoch_elapsed)}
# Epoch 331, gen loss=11.379270553588867,disc loss=0.08544796705245972, {hms_string(epoch_elapsed)}
# Epoch 332, gen loss=11.592682838439941,disc loss=0.12145303934812546, {hms_string(epoch_elapsed)}
# Epoch 333, gen loss=11.453749656677246,disc loss=0.1303514987230301, {hms_string(epoch_elapsed)}
# Epoch 334, gen loss=11.908529281616211,disc loss=0.10153141617774963, {hms_string(epoch_elapsed)}
# Epoch 335, gen loss=11.417715072631836,disc loss=0.10080020129680634, {hms_string(epoch_elapsed)}
# Epoch 336, gen loss=11.629511833190918,disc loss=0.16920159757137299, {hms_string(epoch_elapsed)}
# Epoch 337, gen loss=11.799735069274902,disc loss=0.12700042128562927, {hms_string(epoch_elapsed)}
# Epoch 338, gen loss=11.584783554077148,disc loss=0.10758824646472931, {hms_string(epoch_elapsed)}
# Epoch 339, gen loss=11.616593360900879,disc loss=0.12174557149410248, {hms_string(epoch_elapsed)}
# Epoch 340, gen loss=11.587896347045898,disc loss=0.1247650533914566, {hms_string(epoch_elapsed)}
# Epoch 341, gen loss=11.689313888549805,disc loss=0.06658788025379181, {hms_string(epoch_elapsed)}
# Epoch 342, gen loss=11.901998519897461,disc loss=0.07883518189191818, {hms_string(epoch_elapsed)}
# Epoch 343, gen loss=11.550176620483398,disc loss=0.08540753275156021, {hms_string(epoch_elapsed)}
# Epoch 344, gen loss=11.834222793579102,disc loss=0.10269756615161896, {hms_string(epoch_elapsed)}
# Epoch 345, gen loss=12.267439842224121,disc loss=0.12729711830615997, {hms_string(epoch_elapsed)}
# Epoch 346, gen loss=11.593244552612305,disc loss=0.12342915683984756, {hms_string(epoch_elapsed)}
# Epoch 347, gen loss=11.868824005126953,disc loss=0.10108254104852676, {hms_string(epoch_elapsed)}
# Epoch 348, gen loss=11.927183151245117,disc loss=0.09580293297767639, {hms_string(epoch_elapsed)}
# Epoch 349, gen loss=12.308927536010742,disc loss=0.09179619699716568, {hms_string(epoch_elapsed)}
# Epoch 350, gen loss=11.774653434753418,disc loss=0.14915387332439423, {hms_string(epoch_elapsed)}
# Epoch 351, gen loss=11.577138900756836,disc loss=0.10682664811611176, {hms_string(epoch_elapsed)}
# Epoch 352, gen loss=11.937447547912598,disc loss=0.13037367165088654, {hms_string(epoch_elapsed)}
# Epoch 353, gen loss=11.76269817352295,disc loss=0.1201363354921341, {hms_string(epoch_elapsed)}
# Epoch 354, gen loss=12.051761627197266,disc loss=0.10796119272708893, {hms_string(epoch_elapsed)}
# Epoch 355, gen loss=11.998197555541992,disc loss=0.0768255889415741, {hms_string(epoch_elapsed)}
# Epoch 356, gen loss=11.861546516418457,disc loss=0.11922232061624527, {hms_string(epoch_elapsed)}
# Epoch 357, gen loss=12.023961067199707,disc loss=0.15595130622386932, {hms_string(epoch_elapsed)}
# Epoch 358, gen loss=12.056255340576172,disc loss=0.08916794508695602, {hms_string(epoch_elapsed)}
# Epoch 359, gen loss=11.941020965576172,disc loss=0.16821473836898804, {hms_string(epoch_elapsed)}
# Epoch 360, gen loss=11.753042221069336,disc loss=0.10817048698663712, {hms_string(epoch_elapsed)}
# Epoch 361, gen loss=11.814607620239258,disc loss=0.08980633318424225, {hms_string(epoch_elapsed)}
# Epoch 362, gen loss=12.052846908569336,disc loss=0.09404195100069046, {hms_string(epoch_elapsed)}
# Epoch 363, gen loss=12.07886791229248,disc loss=0.0871281698346138, {hms_string(epoch_elapsed)}
# Epoch 364, gen loss=12.071737289428711,disc loss=0.1351012885570526, {hms_string(epoch_elapsed)}
# Epoch 365, gen loss=11.68120002746582,disc loss=0.10051120817661285, {hms_string(epoch_elapsed)}
# Epoch 366, gen loss=11.844130516052246,disc loss=0.12552931904792786, {hms_string(epoch_elapsed)}
# Epoch 367, gen loss=11.985350608825684,disc loss=0.09348217397928238, {hms_string(epoch_elapsed)}
# Epoch 368, gen loss=11.705507278442383,disc loss=0.10051842778921127, {hms_string(epoch_elapsed)}
# Epoch 369, gen loss=11.665489196777344,disc loss=0.15189774334430695, {hms_string(epoch_elapsed)}
# Epoch 370, gen loss=11.97111701965332,disc loss=0.09481173008680344, {hms_string(epoch_elapsed)}
# Epoch 371, gen loss=12.266536712646484,disc loss=0.09516587853431702, {hms_string(epoch_elapsed)}
# Epoch 372, gen loss=11.90247917175293,disc loss=0.10317755490541458, {hms_string(epoch_elapsed)}
# Epoch 373, gen loss=11.835769653320312,disc loss=0.08706766366958618, {hms_string(epoch_elapsed)}
# Epoch 374, gen loss=12.378072738647461,disc loss=0.11624303460121155, {hms_string(epoch_elapsed)}
# Epoch 375, gen loss=11.677306175231934,disc loss=0.13119742274284363, {hms_string(epoch_elapsed)}
# Epoch 376, gen loss=12.033214569091797,disc loss=0.14026802778244019, {hms_string(epoch_elapsed)}
# Epoch 377, gen loss=11.599346160888672,disc loss=0.12754909694194794, {hms_string(epoch_elapsed)}
# Epoch 378, gen loss=12.101289749145508,disc loss=0.10826515406370163, {hms_string(epoch_elapsed)}
# Epoch 379, gen loss=11.84223747253418,disc loss=0.0980883538722992, {hms_string(epoch_elapsed)}
# Epoch 380, gen loss=12.148849487304688,disc loss=0.10175300389528275, {hms_string(epoch_elapsed)}
# Epoch 381, gen loss=12.055168151855469,disc loss=0.08677417784929276, {hms_string(epoch_elapsed)}
# Epoch 382, gen loss=12.257386207580566,disc loss=0.095587357878685, {hms_string(epoch_elapsed)}
# Epoch 383, gen loss=12.353595733642578,disc loss=0.10686836391687393, {hms_string(epoch_elapsed)}
# Epoch 384, gen loss=12.266325950622559,disc loss=0.0919928029179573, {hms_string(epoch_elapsed)}
# Epoch 385, gen loss=12.225005149841309,disc loss=0.09352340549230576, {hms_string(epoch_elapsed)}
# Epoch 386, gen loss=12.079564094543457,disc loss=0.06010444834828377, {hms_string(epoch_elapsed)}
# Epoch 387, gen loss=12.417880058288574,disc loss=0.08232691138982773, {hms_string(epoch_elapsed)}
# Epoch 388, gen loss=12.346260070800781,disc loss=0.11014210432767868, {hms_string(epoch_elapsed)}
# Epoch 389, gen loss=12.516092300415039,disc loss=0.14904487133026123, {hms_string(epoch_elapsed)}
# Epoch 390, gen loss=11.944433212280273,disc loss=0.11749225854873657, {hms_string(epoch_elapsed)}
# Epoch 391, gen loss=12.32607364654541,disc loss=0.07974129170179367, {hms_string(epoch_elapsed)}
# Epoch 392, gen loss=12.398409843444824,disc loss=0.09515098482370377, {hms_string(epoch_elapsed)}
# Epoch 393, gen loss=12.187255859375,disc loss=0.05979068949818611, {hms_string(epoch_elapsed)}
# Epoch 394, gen loss=13.070441246032715,disc loss=0.1230432391166687, {hms_string(epoch_elapsed)}
# Epoch 395, gen loss=12.70030689239502,disc loss=0.13219957053661346, {hms_string(epoch_elapsed)}
# Epoch 396, gen loss=12.49478530883789,disc loss=0.06979645043611526, {hms_string(epoch_elapsed)}

# %%
generator.save(os.path.join(DATA_PATH,"face_generator.h5"))
